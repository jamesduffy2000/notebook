# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular data science languages are:
#
# 1. Python
# 2. Julia
# 3. R
# 4. SQL
# 5. CSS

# %% [markdown]
# Some commonly used libraries are:
#
# 1. Matplotlib
# 2. seaborn
# 3. pandas

# %% [markdown]
# Some data science tools include:
#
# 1. Databricks
# 2. Amazon web services
# 3. Azure

# %% [markdown]
# Here are a few examples of evaluating arithmetic expressions in python:

# %%
# Example 1: Basic arithmetic
result1 = 3 + 5 * 2
print(result1)  # Output: 13

# Example 2: Using parentheses to change precedence
result2 = (3 + 5) * 2
print(result2)  # Output: 16

# Example 3: Division and subtraction
result3 = 10 / 2 - 3
print(result3)  # Output: 2.0
# Out:
# 13
# 16
# 2.0

# %%
# this is a simple arithmetic expression to multiply and add integers

(3*4)+5
# Out:
# 17

# %%
# Convert minutes to hours
def minutes_to_hours(minutes):
    hours = minutes / 60
    return hours

# Example usage
minutes = 150
converted_hours = minutes_to_hours(minutes)
print(f"{minutes} minutes is equal to {converted_hours:.2f} hours")
# Out:
# 150 minutes is equal to 2.50 hours

# %% [markdown]
# ## Objectives
#
# The objectives of this doucment were to explain some of the key data science libraries, packages, and tools, and to provide some basic examples of pyhton code and markdown usage.

# %% [markdown]
# ## Author: James Duffy

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
